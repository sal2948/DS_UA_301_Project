# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import glob
import torch
from PIL import Image
from torch import nn
import torch
from torchvision import transforms, models
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import classification_report, confusion_matrix

# %%
class PCNN(nn.Module):
    def __init__(self):
        super(PCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 12 * 12, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, 2)  # happy or sad

        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(x.size(0), -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.fc3(x)
        return x
class SCNN(nn.Module):
    def __init__(self):
        super(SCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv4 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv5 = nn.Conv2d(256, 512, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(512 * 3 * 3, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, 4)

        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 100 -> 50
        x = self.pool(F.relu(self.conv2(x)))  # 50 -> 25
        x = self.pool(F.relu(self.conv3(x)))  # 25 -> 12
        x = self.pool(F.relu(self.conv4(x)))  # 12 -> 6
        x = self.pool(F.relu(self.conv5(x)))  # 6 -> 3
        x = x.view(x.size(0), -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        return self.fc3(x)
class HybridEmotionRecognizer:
    def __init__(self, pcnn, scnn, device='cuda'):
        self.pcnn = pcnn.to(device).eval()
        self.scnn = scnn.to(device).eval()
        self.device = device

        self.sub_emotion_map = {
            0: 'surprise',  # Happy path
            1: 'neutral',
            2: 'angry',     # Sad path
            3: 'fear'
        }

    def predict(self, image_tensor):
        with torch.no_grad():
            image_tensor = image_tensor.to(self.device)

            # P-CNN
            primary_logits = self.pcnn(image_tensor)
            primary_class = torch.argmax(primary_logits, dim=1).item()  # 0 = happy, 1 = sad

            # S-CNN
            sub_logits = self.scnn(image_tensor)
            sub_class = torch.argmax(sub_logits, dim=1).item()

            # Interpret result based on primary emotion
            print("primary_class:", primary_class)
            if primary_class == 0:  # Happy
                label = self.sub_emotion_map[sub_class if sub_class in [0, 1] else 1] # default neutral
                print("the subclass:", sub_class)
            else:  # Sad
                label = self.sub_emotion_map[sub_class if sub_class in [2, 3] else 2] # default anger
                print("the subclass:", sub_class)

        return {
            "primary": "happy" if primary_class == 0 else "sad",
            "secondary": label
        }

# %%
p_model = PCNN()
s_model = SCNN()

p_model.load_state_dict(torch.load("/content/drive/MyDrive/RAF_DB_analysis/saved_models/pcnn_model.pth", map_location=torch.device('cuda')))
s_model.load_state_dict(torch.load("/content/drive/MyDrive/RAF_DB_analysis/saved_models/scnn_model.pth", map_location=torch.device('cuda')))

p_model.eval()
s_model.eval()
# Out:
# SCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
class ImgDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform or transforms.ToTensor()

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert("RGB")
        if self.transform:
            img = self.transform(img)
        label = self.labels[idx]
        return img, label

# load dataset
path = "/content/drive/MyDrive/RAF_DB_analysis/AffectNetCustom/test"
image_paths = []
labels = []
for label_str in sorted(os.listdir(path)):
    label_path = os.path.join(path, label_str)
    if not os.path.isdir(label_path):
        continue
    files = glob.glob(os.path.join(label_path, '*.jpg'))
    image_paths.extend(files)
    # Folder name = label ID (0–6)
    labels.extend([int(label_str)] * len(files))
transform = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.ToTensor(),
])
dataset = ImgDataset(image_paths, labels, transform)
loader = DataLoader(dataset, batch_size=32, shuffle=False)

# %%
def evaluate_hybrid(hybrid_model, loader, device="cuda"):
    valid_labels = {
        5: 0,  # surprise
        6: 1,  # neutral
        0: 2,  # angry
        2: 3   # fear
    }
    subclass_map = {
        "surprise": 0,
        "neutral": 1,
        "angry": 2,
        "fear": 3
    }
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            for i in range(images.size(0)):
                label = labels[i].item()
                if label not in valid_labels:
                    continue
                img = images[i].unsqueeze(0).to(device)
                pred = hybrid_model.predict(img)
                expected_subclass = valid_labels[label]
                expected_primary = 0 if expected_subclass in [0, 1] else 1
                pred_subclass = subclass_map.get(pred["secondary"], -1)
                pred_primary = 0 if pred["primary"] == "happy" else 1
                if pred_primary == expected_primary and pred_subclass == expected_subclass:
                    correct += 1
                total += 1
    acc = correct / total if total > 0 else 0
    print(f"Hybrid Test Accuracy (Secondary emotion path only): {acc:.4f} on {total} samples")
    return acc, total

# %%
pipeline = HybridEmotionRecognizer(p_model, s_model)
evaluate_hybrid(pipeline, loader)
# Out:
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 0
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 0
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 1
# the subclass: 1
# primary_class: 0
# the subclass: 1
# primary_class: 0
# the subclass: 3
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 1
# primary_class: 1
# the subclass: 2
# primary_class: 0
# the subclass: 3
# Hybrid Test Accuracy (Secondary emotion path only): 0.3252 on 1599 samples
# (0.3252032520325203, 1599)

# %%
#transfer learning with Resnet
def build_resnet_finetune(num_classes=7):
    resnet = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
    for param in resnet.parameters():
        param.requires_grad = False
    # Replace final layer
    in_features = resnet.fc.in_features
    resnet.fc = nn.Sequential(
        nn.Linear(in_features, 256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, num_classes)
    )
    return resnet

# %%
resnet_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
#read training and testing data
data_dir   = '/content/drive/MyDrive/RAF_DB_analysis/RAF_DB/'

test_dir = data_dir + 'DATASET/test/'
train_dir = data_dir + 'DATASET/train/'

test_csv  = pd.read_csv(data_dir + 'test_labels.csv')
train_csv = pd.read_csv(data_dir + 'train_labels.csv')

# %%
test_label = test_csv['label'].to_list()
test_label = [label - 1 for label in test_label]
test_img = [test_dir+str(r['label'])+'/'+r['image'] for idx, r in test_csv.iterrows()]
train_label = train_csv['label'].to_list()
train_label = [label - 1 for label in train_label]
train_img = [train_dir+str(r['label'])+'/'+r['image'] for idx, r in train_csv.iterrows()]

# %%
dataset_train = ImgDataset(train_img, train_label, resnet_transform)
loader_train = DataLoader(dataset, batch_size=32, shuffle=False)
dataset_test = ImgDataset(test_img, test_label, resnet_transform)
loader_test = DataLoader(dataset_test, batch_size=32, shuffle=False)

# %%
def train_resnet(model, train_loader, val_loader, num_epochs=64, lr=1e-5, device="cuda"):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=lr)
    for name, param in model.named_parameters():
        if "layer2" in name or "layer3" in name or "layer4" in name or "fc" in name:
            param.requires_grad = True
        else:
            param.requires_grad = False
    print("Training ResNet...")
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

        train_acc = train_correct / train_total

        # Validate
        if val_loader:
            model.eval()
            val_loss = 0
            val_correct = 0
            val_total = 0
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(device), labels.to(device)

                    outputs = model(images)
                    loss = criterion(outputs, labels)

                    val_loss += loss.item()
                    preds = outputs.argmax(dim=1)
                    val_correct += (preds == labels).sum().item()
                    val_total += labels.size(0)
            val_acc = val_correct / val_total
            print(f"Epoch {epoch+1}/{num_epochs} - "
                f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} | "
                f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
        else:
            print(f"Epoch {epoch+1}/{num_epochs} - "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")

# %%
def evaluate_resnet(model, test_loader, fer_mapping, device="cuda"):
    model.to(device)
    model.eval()

    all_preds = []
    all_labels = []
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            preds = outputs.argmax(dim=1).cpu().numpy()
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds)
            all_labels.extend(labels.numpy())
    acc = correct / total
    print("Test Set Classification Report:\n",
          classification_report(all_labels, all_preds, target_names=list(fer_mapping.keys())))
    print("Test Set Confusion Matrix:\n", confusion_matrix(all_labels, all_preds))
    print(f"overall test accuracy: {acc:.4f}")

# %%
resnet_model = build_resnet_finetune()
train_resnet(resnet_model, loader_train, num_epochs= 200, val_loader=None, lr = 1e-5)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 225MB/s]
# Training ResNet...
# Epoch 1/200 - Train Loss: 184.9673, Train Acc: 0.0486
# Epoch 2/200 - Train Loss: 180.2117, Train Acc: 0.0507
# Epoch 3/200 - Train Loss: 178.9487, Train Acc: 0.0532
# Epoch 4/200 - Train Loss: 177.4681, Train Acc: 0.0514
# Epoch 5/200 - Train Loss: 176.6089, Train Acc: 0.0547
# Epoch 6/200 - Train Loss: 175.8305, Train Acc: 0.0622
# Epoch 7/200 - Train Loss: 175.4280, Train Acc: 0.0629
# Epoch 8/200 - Train Loss: 174.7903, Train Acc: 0.0650
# Epoch 9/200 - Train Loss: 174.5075, Train Acc: 0.0693
# Epoch 10/200 - Train Loss: 174.0180, Train Acc: 0.0779
# Epoch 11/200 - Train Loss: 173.5728, Train Acc: 0.0815
# Epoch 12/200 - Train Loss: 173.3720, Train Acc: 0.0886
# Epoch 13/200 - Train Loss: 173.1078, Train Acc: 0.0997
# Epoch 14/200 - Train Loss: 172.9278, Train Acc: 0.0907
# Epoch 15/200 - Train Loss: 172.6338, Train Acc: 0.0993
# Epoch 16/200 - Train Loss: 172.5420, Train Acc: 0.1043
# Epoch 17/200 - Train Loss: 172.3482, Train Acc: 0.0997
# Epoch 18/200 - Train Loss: 172.1594, Train Acc: 0.1200
# Epoch 19/200 - Train Loss: 172.0234, Train Acc: 0.1161
# Epoch 20/200 - Train Loss: 171.9002, Train Acc: 0.1325
# Epoch 21/200 - Train Loss: 171.7787, Train Acc: 0.1308
# Epoch 22/200 - Train Loss: 171.6512, Train Acc: 0.1454
# Epoch 23/200 - Train Loss: 171.6523, Train Acc: 0.1297
# Epoch 24/200 - Train Loss: 171.3906, Train Acc: 0.1490
# Epoch 25/200 - Train Loss: 171.4584, Train Acc: 0.1454
# Epoch 26/200 - Train Loss: 171.2902, Train Acc: 0.1476
# Epoch 27/200 - Train Loss: 171.2627, Train Acc: 0.1565
# Epoch 28/200 - Train Loss: 171.1194, Train Acc: 0.1618
# Epoch 29/200 - Train Loss: 171.0114, Train Acc: 0.1626
# Epoch 30/200 - Train Loss: 171.0235, Train Acc: 0.1697
# Epoch 31/200 - Train Loss: 170.8970, Train Acc: 0.1622
# Epoch 32/200 - Train Loss: 170.7551, Train Acc: 0.1729
# Epoch 33/200 - Train Loss: 170.7644, Train Acc: 0.1736
# Epoch 34/200 - Train Loss: 170.6842, Train Acc: 0.1776
# Epoch 35/200 - Train Loss: 170.5556, Train Acc: 0.1915
# Epoch 36/200 - Train Loss: 170.4839, Train Acc: 0.1929
# Epoch 37/200 - Train Loss: 170.3671, Train Acc: 0.1926
# Epoch 38/200 - Train Loss: 170.4251, Train Acc: 0.1851
# Epoch 39/200 - Train Loss: 170.2379, Train Acc: 0.2011
# Epoch 40/200 - Train Loss: 170.1948, Train Acc: 0.2097
# Epoch 41/200 - Train Loss: 170.0203, Train Acc: 0.2151
# Epoch 42/200 - Train Loss: 170.1065, Train Acc: 0.2136
# Epoch 43/200 - Train Loss: 169.9727, Train Acc: 0.2272
# Epoch 44/200 - Train Loss: 169.8580, Train Acc: 0.2315
# Epoch 45/200 - Train Loss: 169.8149, Train Acc: 0.2251
# Epoch 46/200 - Train Loss: 169.7439, Train Acc: 0.2251
# Epoch 47/200 - Train Loss: 169.6436, Train Acc: 0.2369
# Epoch 48/200 - Train Loss: 169.5332, Train Acc: 0.2551
# Epoch 49/200 - Train Loss: 169.3899, Train Acc: 0.2687
# Epoch 50/200 - Train Loss: 169.3792, Train Acc: 0.2587
# Epoch 51/200 - Train Loss: 169.2367, Train Acc: 0.2576
# Epoch 52/200 - Train Loss: 169.2116, Train Acc: 0.2687
# Epoch 53/200 - Train Loss: 169.0732, Train Acc: 0.2751
# Epoch 54/200 - Train Loss: 168.9503, Train Acc: 0.2851
# Epoch 55/200 - Train Loss: 168.9813, Train Acc: 0.2797
# Epoch 56/200 - Train Loss: 168.7879, Train Acc: 0.2890
# Epoch 57/200 - Train Loss: 168.7546, Train Acc: 0.2958
# Epoch 58/200 - Train Loss: 168.7278, Train Acc: 0.2955
# Epoch 59/200 - Train Loss: 168.5611, Train Acc: 0.3105
# Epoch 60/200 - Train Loss: 168.4819, Train Acc: 0.2987
# Epoch 61/200 - Train Loss: 168.3901, Train Acc: 0.3183
# Epoch 62/200 - Train Loss: 168.2484, Train Acc: 0.3169
# Epoch 63/200 - Train Loss: 168.1517, Train Acc: 0.3165
# Epoch 64/200 - Train Loss: 168.1218, Train Acc: 0.3315
# Epoch 65/200 - Train Loss: 168.0527, Train Acc: 0.3269
# Epoch 66/200 - Train Loss: 167.8814, Train Acc: 0.3501
# Epoch 67/200 - Train Loss: 167.7996, Train Acc: 0.3305
# Epoch 68/200 - Train Loss: 167.7246, Train Acc: 0.3433
# Epoch 69/200 - Train Loss: 167.6233, Train Acc: 0.3448
# Epoch 70/200 - Train Loss: 167.5061, Train Acc: 0.3526
# Epoch 71/200 - Train Loss: 167.5338, Train Acc: 0.3505
# Epoch 72/200 - Train Loss: 167.2768, Train Acc: 0.3623
# Epoch 73/200 - Train Loss: 167.3168, Train Acc: 0.3541
# Epoch 74/200 - Train Loss: 167.0672, Train Acc: 0.3683
# Epoch 75/200 - Train Loss: 167.0757, Train Acc: 0.3694
# Epoch 76/200 - Train Loss: 166.9464, Train Acc: 0.3758
# Epoch 77/200 - Train Loss: 166.7312, Train Acc: 0.3819
# Epoch 78/200 - Train Loss: 166.7526, Train Acc: 0.3876
# Epoch 79/200 - Train Loss: 166.5651, Train Acc: 0.3880
# Epoch 80/200 - Train Loss: 166.5215, Train Acc: 0.3905
# Epoch 81/200 - Train Loss: 166.3416, Train Acc: 0.3951
# Epoch 82/200 - Train Loss: 166.2689, Train Acc: 0.4037
# Epoch 83/200 - Train Loss: 166.0791, Train Acc: 0.4130
# Epoch 84/200 - Train Loss: 166.1671, Train Acc: 0.4041
# Epoch 85/200 - Train Loss: 166.1355, Train Acc: 0.3930
# Epoch 86/200 - Train Loss: 165.8149, Train Acc: 0.4230
# Epoch 87/200 - Train Loss: 165.7484, Train Acc: 0.4262
# Epoch 88/200 - Train Loss: 165.6548, Train Acc: 0.4227
# Epoch 89/200 - Train Loss: 165.3757, Train Acc: 0.4380
# Epoch 90/200 - Train Loss: 165.3671, Train Acc: 0.4294
# Epoch 91/200 - Train Loss: 165.2286, Train Acc: 0.4427
# Epoch 92/200 - Train Loss: 165.1853, Train Acc: 0.4244
# Epoch 93/200 - Train Loss: 165.0552, Train Acc: 0.4469
# Epoch 94/200 - Train Loss: 164.7924, Train Acc: 0.4491
# Epoch 95/200 - Train Loss: 164.8511, Train Acc: 0.4484
# Epoch 96/200 - Train Loss: 164.7232, Train Acc: 0.4677
# Epoch 97/200 - Train Loss: 164.5190, Train Acc: 0.4745
# Epoch 98/200 - Train Loss: 164.4582, Train Acc: 0.4580
# Epoch 99/200 - Train Loss: 164.4118, Train Acc: 0.4677
# Epoch 100/200 - Train Loss: 164.3035, Train Acc: 0.4605
# Epoch 101/200 - Train Loss: 164.1028, Train Acc: 0.4727
# Epoch 102/200 - Train Loss: 164.0378, Train Acc: 0.4759
# Epoch 103/200 - Train Loss: 163.9299, Train Acc: 0.4741
# Epoch 104/200 - Train Loss: 163.7275, Train Acc: 0.4780
# Epoch 105/200 - Train Loss: 163.5324, Train Acc: 0.4962
# Epoch 106/200 - Train Loss: 163.4249, Train Acc: 0.4948
# Epoch 107/200 - Train Loss: 163.3175, Train Acc: 0.5052
# Epoch 108/200 - Train Loss: 163.3051, Train Acc: 0.4934
# Epoch 109/200 - Train Loss: 163.0830, Train Acc: 0.5041
# Epoch 110/200 - Train Loss: 163.0865, Train Acc: 0.5080
# Epoch 111/200 - Train Loss: 162.7450, Train Acc: 0.5205
# Epoch 112/200 - Train Loss: 162.7532, Train Acc: 0.5073
# Epoch 113/200 - Train Loss: 162.6829, Train Acc: 0.5009
# Epoch 114/200 - Train Loss: 162.5504, Train Acc: 0.5163
# Epoch 115/200 - Train Loss: 162.3086, Train Acc: 0.5195
# Epoch 116/200 - Train Loss: 162.2506, Train Acc: 0.5220
# Epoch 117/200 - Train Loss: 162.0449, Train Acc: 0.5334
# Epoch 118/200 - Train Loss: 161.9790, Train Acc: 0.5352
# Epoch 119/200 - Train Loss: 161.7458, Train Acc: 0.5373
# Epoch 120/200 - Train Loss: 161.5928, Train Acc: 0.5352
# Epoch 121/200 - Train Loss: 161.5103, Train Acc: 0.5463
# Epoch 122/200 - Train Loss: 161.4189, Train Acc: 0.5398
# Epoch 123/200 - Train Loss: 161.1849, Train Acc: 0.5648
# Epoch 124/200 - Train Loss: 161.0441, Train Acc: 0.5563
# Epoch 125/200 - Train Loss: 161.0296, Train Acc: 0.5456
# Epoch 126/200 - Train Loss: 160.8472, Train Acc: 0.5666
# Epoch 127/200 - Train Loss: 160.6245, Train Acc: 0.5688
# Epoch 128/200 - Train Loss: 160.5436, Train Acc: 0.5570
# Epoch 129/200 - Train Loss: 160.6026, Train Acc: 0.5616
# Epoch 130/200 - Train Loss: 160.1893, Train Acc: 0.5716
# Epoch 131/200 - Train Loss: 160.1659, Train Acc: 0.5720
# Epoch 132/200 - Train Loss: 160.0007, Train Acc: 0.5806
# Epoch 133/200 - Train Loss: 159.8488, Train Acc: 0.5731
# Epoch 134/200 - Train Loss: 159.6929, Train Acc: 0.5888
# Epoch 135/200 - Train Loss: 159.5658, Train Acc: 0.5824
# Epoch 136/200 - Train Loss: 159.3315, Train Acc: 0.5899
# Epoch 137/200 - Train Loss: 159.3421, Train Acc: 0.5902
# Epoch 138/200 - Train Loss: 159.0895, Train Acc: 0.5866
# Epoch 139/200 - Train Loss: 158.8820, Train Acc: 0.5952
# Epoch 140/200 - Train Loss: 158.7803, Train Acc: 0.5949
# Epoch 141/200 - Train Loss: 158.8046, Train Acc: 0.5974
# Epoch 142/200 - Train Loss: 158.6975, Train Acc: 0.6006
# Epoch 143/200 - Train Loss: 158.4673, Train Acc: 0.6084
# Epoch 144/200 - Train Loss: 158.3344, Train Acc: 0.5991
# Epoch 145/200 - Train Loss: 158.0571, Train Acc: 0.6041
# Epoch 146/200 - Train Loss: 158.1188, Train Acc: 0.5984
# Epoch 147/200 - Train Loss: 157.9781, Train Acc: 0.6127
# Epoch 148/200 - Train Loss: 157.6602, Train Acc: 0.6184
# Epoch 149/200 - Train Loss: 157.4991, Train Acc: 0.6181
# Epoch 150/200 - Train Loss: 157.3505, Train Acc: 0.6149
# Epoch 151/200 - Train Loss: 157.1672, Train Acc: 0.6295
# Epoch 152/200 - Train Loss: 156.9597, Train Acc: 0.6263
# Epoch 153/200 - Train Loss: 157.0202, Train Acc: 0.6170
# Epoch 154/200 - Train Loss: 156.8208, Train Acc: 0.6270
# Epoch 155/200 - Train Loss: 156.6769, Train Acc: 0.6209
# Epoch 156/200 - Train Loss: 156.3634, Train Acc: 0.6231
# Epoch 157/200 - Train Loss: 156.3769, Train Acc: 0.6277
# Epoch 158/200 - Train Loss: 156.0784, Train Acc: 0.6352
# Epoch 159/200 - Train Loss: 155.8072, Train Acc: 0.6374
# Epoch 160/200 - Train Loss: 155.5801, Train Acc: 0.6488
# Epoch 161/200 - Train Loss: 155.6255, Train Acc: 0.6442
# Epoch 162/200 - Train Loss: 155.5382, Train Acc: 0.6342
# Epoch 163/200 - Train Loss: 155.4091, Train Acc: 0.6309
# Epoch 164/200 - Train Loss: 155.2811, Train Acc: 0.6449
# Epoch 165/200 - Train Loss: 154.7792, Train Acc: 0.6527
# Epoch 166/200 - Train Loss: 154.5915, Train Acc: 0.6770
# Epoch 167/200 - Train Loss: 154.7001, Train Acc: 0.6459
# Epoch 168/200 - Train Loss: 154.2948, Train Acc: 0.6563
# Epoch 169/200 - Train Loss: 154.3311, Train Acc: 0.6584
# Epoch 170/200 - Train Loss: 154.2268, Train Acc: 0.6538
# Epoch 171/200 - Train Loss: 153.9837, Train Acc: 0.6656
# Epoch 172/200 - Train Loss: 153.8278, Train Acc: 0.6499
# Epoch 173/200 - Train Loss: 153.8255, Train Acc: 0.6481
# Epoch 174/200 - Train Loss: 153.6350, Train Acc: 0.6685
# Epoch 175/200 - Train Loss: 153.4491, Train Acc: 0.6681
# Epoch 176/200 - Train Loss: 153.2225, Train Acc: 0.6745
# Epoch 177/200 - Train Loss: 153.2937, Train Acc: 0.6727
# Epoch 178/200 - Train Loss: 152.8692, Train Acc: 0.6799
# Epoch 179/200 - Train Loss: 152.5624, Train Acc: 0.6710
# Epoch 180/200 - Train Loss: 152.4934, Train Acc: 0.6670
# Epoch 181/200 - Train Loss: 152.3290, Train Acc: 0.6845
# Epoch 182/200 - Train Loss: 152.2030, Train Acc: 0.6870
# Epoch 183/200 - Train Loss: 152.1088, Train Acc: 0.6695
# Epoch 184/200 - Train Loss: 151.6215, Train Acc: 0.6849
# Epoch 185/200 - Train Loss: 151.7590, Train Acc: 0.6774
# Epoch 186/200 - Train Loss: 151.3139, Train Acc: 0.6827
# Epoch 187/200 - Train Loss: 151.3487, Train Acc: 0.6842
# Epoch 188/200 - Train Loss: 150.9167, Train Acc: 0.7028
# Epoch 189/200 - Train Loss: 150.8892, Train Acc: 0.6842
# Epoch 190/200 - Train Loss: 150.5197, Train Acc: 0.6852
# Epoch 191/200 - Train Loss: 150.8362, Train Acc: 0.6952
# Epoch 192/200 - Train Loss: 150.2420, Train Acc: 0.6977
# Epoch 193/200 - Train Loss: 150.3605, Train Acc: 0.6927
# Epoch 194/200 - Train Loss: 149.9630, Train Acc: 0.7017
# Epoch 195/200 - Train Loss: 149.8570, Train Acc: 0.6974
# Epoch 196/200 - Train Loss: 149.6815, Train Acc: 0.7038
# Epoch 197/200 - Train Loss: 149.5778, Train Acc: 0.7035
# Epoch 198/200 - Train Loss: 149.3446, Train Acc: 0.7049
# Epoch 199/200 - Train Loss: 149.2372, Train Acc: 0.6977
# Epoch 200/200 - Train Loss: 148.9851, Train Acc: 0.7031

# %%
torch.save(resnet_model.state_dict(), 'resnet_model.pth')

# %%
fer_mapping_raf = {
    'surprise': 0,
    'fear': 1,
    'disgust': 2,
    'happy': 3,
    'sad': 4,
    'angry': 5,
    'neutral': 6
}
evaluate_resnet(resnet_model, loader_test,fer_mapping_raf)
# Out:
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#     surprise       0.00      0.00      0.00       329
#         fear       0.12      0.05      0.08        74
#      disgust       0.07      0.22      0.10       160
#        happy       0.38      0.07      0.12      1185
#          sad       0.19      0.08      0.11       478
#        angry       0.05      0.15      0.07       162
#      neutral       0.24      0.54      0.33       680
#
#     accuracy                           0.18      3068
#    macro avg       0.15      0.16      0.12      3068
# weighted avg       0.24      0.18      0.15      3068
#
# Test Set Confusion Matrix:
#  [[  0   4  55  22  20  70 158]
#  [  0   4   7   7   2   7  47]
#  [  0   4  35  10   6  26  79]
#  [  1   7 208  88  98 203 580]
#  [  0   5 100  39  38  69 227]
#  [  0   4  17  19   7  24  91]
#  [  0   4 105  45  32 125 369]]
# overall test accuracy: 0.1819

# %%
def collect_image_paths_and_labels(root_dir, label_map):
    image_paths = []
    labels = []
    for label_name, label_idx in label_map.items():
        folder_path = os.path.join(root_dir, label_name)
        for fname in os.listdir(folder_path):
            if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_paths.append(os.path.join(folder_path, fname))
                labels.append(label_idx)
    return image_paths, labels
root_fer_test = '/content/drive/MyDrive/RAF_DB_analysis/FER/test'
root_fer_train = '/content/drive/MyDrive/RAF_DB_analysis/FER/train'
fer_label_map = {
    'angry': 0,
    'disgust': 1,
    'fear': 2,
    'happy': 3,
    'sad': 4,
    'surprise': 5,
    'neutral': 6
}
fer_train_images, fer_train_labels =collect_image_paths_and_labels(root_fer_train, fer_label_map)
fer_test_images, fer_test_labels = collect_image_paths_and_labels(root_fer_test, fer_label_map)
fer_train_dataset = ImgDataset(fer_train_images, fer_train_labels, transform=resnet_transform)
fer_train_loader = DataLoader(fer_train_dataset, batch_size=64, shuffle=False)
fer_test_dataset = ImgDataset(fer_test_images, fer_test_labels, transform=resnet_transform)
fer_test_loader = DataLoader(fer_test_dataset, batch_size=64, shuffle=False)

# %%
resnet_model_fer = build_resnet_finetune()
train_resnet(resnet_model_fer, fer_train_loader, val_loader=None, num_epochs = 20, lr = 1e-5)
# Out:
# Training ResNet...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9effa7f07e72> in <cell line: 0>()
#       1 resnet_model_fer = build_resnet_finetune()
# ----> 2 train_resnet(resnet_model_fer, fer_train_loader, val_loader=None, num_epochs = 20, lr = 1e-5)
#
# <ipython-input-18-1c06138bce60> in train_resnet(model, train_loader, val_loader, num_epochs, lr, device)
#      15         train_total = 0
#      16
# ---> 17         for images, labels in train_loader:
#      18             images, labels = images.to(device), labels.to(device)
#      19             outputs = model(images)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-11-fb5d972261b1> in __getitem__(self, idx)
#       9
#      10     def __getitem__(self, idx):
# ---> 11         img = Image.open(self.image_paths[idx]).convert("RGB")
#      12         if self.transform:
#      13             img = self.transform(img)
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3514         exclusive_fp = True
#    3515
# -> 3516     prefix = fp.read(16)
#    3517
#    3518     preinit()
#
# KeyboardInterrupt:

# %%
fer_mapping_raf = {
    'surprise': 0,
    'fear': 1,
    'disgust': 2,
    'happy': 3,
    'sad': 4,
    'angry': 5,
    'neutral': 6
}
evaluate_resnet(resnet_model_fer, fer_test_loader,fer_mapping_raf)
